# %%
import numpy as np
import pandas as pd

# %%
data_set =pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', header = None)

# %%
col_labels = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status','occupation','relationship', 'race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week','native_country', 'wage_class']

# %%
data_set.columns = col_labels

# %%
data_set.head(1000)
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country wage_class
# ...

# %%
# Check for Nulls
data_set.info()
# there are no nulls
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education_num     32561 non-null int64
# marital_status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital_gain      32561 non-null int64
# capital_loss      32561 non-null int64
# hours_per_week    32561 non-null int64
# native_country    32561 non-null object
# wage_class        32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 2.6+ MB

# %%
data_set['occupation'] = data_set['occupation'].str.strip()

# %%
data_set['workclass'].str.contains('',regex=False).sum()
# Out:
# 32561

# %%
data_set['workclass'].isnull().any()
# Out:
# False

# %%
# Convert Type Object to Int64

# %%
titanic_work['Sex'] = titanic['Sex'].map({'female':0,'male':1}).astype(int)

# %%
data_set['occupation'] = data_set['occupation'].map({'?':0,'Tech-support':1,'Craft-repair':2,'Other-service':3,'Sales':4,'Exec-managerial':5,'Prof-specialty':6,'Handlers-cleaners':7,'Machine-op-inspct':8,'Adm-clerical':9,'Farming-fishing':10,'Transport-moving':11,'Priv-house-serv':12,'Protective-serv':13,'Armed-Forces':14}).astype(int)

# %%
data_set.head(10)
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0   39          6   77516          1             13               3
# 1   50          2   83311          1             13               1
# 2   38          1  215646          4              9               2
# 3   53          1  234721          3              7               1
# 4   28          1  338409          1             13               1
# 5   37          1  284582         11             14               1
# 6   49          1  160187          8              5               6
# 7   52          2  209642          4              9               1
# 8   31          1   45781         11             14               3
# 9   42          1  159449          1             13               1
#
#    occupation  relationship  race  sex  capital_gain  capital_loss  \
# 0           9             4     1    1          2174             0
# 1           5             3     1    1             0             0
# ...

# %%
data_set['wage_class'] = data_set['wage_class'].str.strip()
data_set['wage_class'] = data_set['wage_class'].map({'<=50K': 0, '>50K': 1}).astype(int)

# %%
data_set['workclass'] = data_set['workclass'].str.strip()

# %%
data_set['workclass'] = data_set['workclass'].map({'?':0,'Private':1, 'Self-emp-not-inc':2, 'Self-emp-inc':3, 'Federal-gov':4, 'Local-gov':5, 'State-gov':6,'Without-pay':7, 'Never-worked':8}).astype(int)

# %%
data_set['education'] = data_set['education'].str.strip()
data_set['education'] = data_set['education'].map({'Bachelors':1, 'Some-college':2, '11th':3, 'HS-grad':4, 'Prof-school':5, 'Assoc-acdm':6, 'Assoc-voc':7,'9th':8, '7th-8th':9, '12th':10, 'Masters':11, '1st-4th':12, '10th':13, 'Doctorate':14, '5th-6th':15, 'Preschool':16}).astype(int)

# %%
data_set['marital_status'] = data_set['marital_status'].str.strip()
data_set['marital_status'] = data_set['marital_status'].map({'Married-civ-spouse':1, 'Divorced':2, 'Never-married':3, 'Separated':4, 'Widowed':5,'Married-spouse-absent':6, 'Married-AF-spouse':7}).astype(int)

# %%
data_set['relationship'] = data_set['relationship'].str.strip()
data_set['relationship'] = data_set['relationship'].map({'Wife':1, 'Own-child':2, 'Husband':3, 'Not-in-family':4, 'Other-relative':5, 'Unmarried':6}).astype(int)

# %%
data_set['race'] = data_set['race'].str.strip()
data_set['race'] = data_set['race'].map({'White':1, 'Asian-Pac-Islander':2, 'Amer-Indian-Eskimo':3, 'Other':4, 'Black':5}).astype(int)

# %%
data_set['sex'] = data_set['sex'].str.strip()
data_set['sex'] = data_set['sex'].map({'Female':0, 'Male':1}).astype(int)

# %%
from sklearn.model_selection import train_test_split

# %%
X=data_set.drop(['wage_class'], axis=1).values
y = data_set['wage_class'].values

# %%
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
data_set.drop(['native_country'],axis=1)
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       39          6   77516          1             13               3
# 1       50          2   83311          1             13               1
# 2       38          1  215646          4              9               2
# 3       53          1  234721          3              7               1
# 4       28          1  338409          1             13               1
# 5       37          1  284582         11             14               1
# 6       49          1  160187          8              5               6
# 7       52          2  209642          4              9               1
# 8       31          1   45781         11             14               3
# 9       42          1  159449          1             13               1
# 10      37          1  280464          2             10               1
# 11      30          6  141297          1             13               1
# ...

# %%
train_set = data_set

# %%
test_set = data_set

# %%
col_labels = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status','occupation','relationship', 'race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'wage_class']

# %%
test_set.head()
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0   39          6   77516          1             13               3
# 1   50          2   83311          1             13               1
# 2   38          1  215646          4              9               2
# 3   53          1  234721          3              7               1
# 4   28          1  338409          1             13               1
#
#    occupation  relationship  race  sex  capital_gain  capital_loss  \
# 0           9             4     1    1          2174             0
# 1           5             3     1    1             0             0
# 2           7             4     1    1             0             0
# 3           7             3     5    1             0             0
# 4           6             1     5    0             0             0
#
#    hours_per_week  wage_class
# 0              40           0
# 1              13           0
# 2              40           0
# ...

# %%
train_set = train_set.drop(['native_country'],axis=1)
test_set = test_set.drop(['native_country'],axis=1)

# %%
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0   39          6   77516          1             13               3
# 1   50          2   83311          1             13               1
# 2   38          1  215646          4              9               2
# 3   53          1  234721          3              7               1
# 4   28          1  338409          1             13               1
#
#    occupation  relationship  race  sex  capital_gain  capital_loss  \
# 0           9             4     1    1          2174             0
# 1           5             3     1    1             0             0
# 2           7             4     1    1             0             0
# 3           7             3     5    1             0             0
# 4           6             1     5    0             0             0
#
#    hours_per_week  wage_class
# 0              40           0
# 1              13           0
# 2              40           0
# ...

# %%
train_set.columnes = col_labels
test_set.columns = col_labels
# Out:
# E:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
import numpy as np
import xgboost as xgb

# %%
('adult_train.dat', 'adult_test.dat'))

# %%
dtrain = xgb.DMatrix('adult_train.dat')
dtest = xgb.DMatrix('adult_test.dat')

# %%
print("Train dataset contains {0} rows and {1} columns".format(dtrain.num_row(), dtrain.num_col()))
print("Test dataset contains {0} rows and {1} columns".format(dtest.num_row(), dtest.num_col()))
# Out:
# Train dataset contains 32561 rows and 13 columns
# Test dataset contains 9768 rows and 13 columns

# %%
print("Train possible labels: ")
print(np.unique(dtrain.get_label()))

print("\nTest possible labels: ")
print(np.unique(dtest.get_label()))
# Out:
# Train possible labels:
# [0. 1.]
#
# Test possible labels:
# [0. 1.]

# %%
params = {
    'objective':'binary:logistic',
    'max_depth':2,
    'silent':1,
    'eta':1
}

num_rounds = 5

# %%
bst = xgb.train(params, dtrain, num_rounds)

# %%
watchlist  = [(dtest,'test'), (dtrain,'train')] # native interface only
bst = xgb.train(params, dtrain, num_rounds, watchlist)
# Out:
# [0]	test-error:0.169943	train-error:0.17177
# [1]	test-error:0.158374	train-error:0.159393
# [2]	test-error:0.153358	train-error:0.153189
# [3]	test-error:0.152437	train-error:0.153036
# [4]	test-error:0.148342	train-error:0.150425

# %%
preds_prob = bst.predict(dtest)
preds_prob
# Out:
# array([0.90965724, 0.0231973 , 0.00458157, ..., 0.13300334, 0.47580436,
#        0.34250093], dtype=float32)

# %%
labels = dtest.get_label()
preds = preds_prob > 0.5 # threshold
correct = 0

for i in range(len(preds)):
    if (labels[i] == preds[i]):
        correct += 1

print('Predicted correctly: {0}/{1}'.format(correct, len(preds)))
print('Error: {0:.4f}'.format(1-correct/len(preds)))
# Out:
# Predicted correctly: 8319/9768
# Error: 0.1483

# %%
#Using Scikit-learn Interface

# %%
from sklearn.datasets import load_svmlight_files
from sklearn.metrics import accuracy_score

# %%
train_set_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32561 entries, 0 to 1
# Data columns (total 13 columns):
# age               32561 non-null int64
# workclass         32561 non-null int32
# fnlwgt            32561 non-null int64
# education         32561 non-null int32
# education_num     32561 non-null int64
# marital_status    32561 non-null int32
# occupation        32561 non-null int32
# relationship      32561 non-null int32
# race              32561 non-null int32
# sex               32561 non-null int32
# capital_gain      32561 non-null int64
# capital_loss      32561 non-null int64
# hours_per_week    32561 non-null int64
# dtypes: int32(7), int64(6)
# memory usage: 2.6 MB

# %%
y = train_set['wage_class']
y = y.astype(float)

# %%
X = train_set.drop(['wage_class'], axis = 1)
X = X.astype(float)
X.head()
# Out:
#     age  workclass    fnlwgt  education  education_num  marital_status  \
# 0  39.0        6.0   77516.0        1.0           13.0             3.0
# 1  50.0        2.0   83311.0        1.0           13.0             1.0
# 2  38.0        1.0  215646.0        4.0            9.0             2.0
# 3  53.0        1.0  234721.0        3.0            7.0             1.0
# 4  28.0        1.0  338409.0        1.0           13.0             1.0
#
#    occupation  relationship  race  sex  capital_gain  capital_loss  \
# 0         9.0           4.0   1.0  1.0        2174.0           0.0
# 1         5.0           3.0   1.0  1.0           0.0           0.0
# 2         7.0           4.0   1.0  1.0           0.0           0.0
# 3         7.0           3.0   5.0  1.0           0.0           0.0
# 4         6.0           1.0   5.0  0.0           0.0           0.0
#
#    hours_per_week
# 0            40.0
# 1            13.0
# 2            40.0
# 3            40.0
# 4            40.0

# %%
from sklearn.datasets import dump_svmlight_file
dump_svmlight_file(X,y,'adult_train.dat',zero_based=True,multilabel=False)

# %%
# Making Test Data SVM file

# %%
test_set_1 = train_set.sample(frac=0.3)

# %%
y_t = test_set_1['wage_class']
y_t = y_t.astype(float)
y_t
# Out:
# 4568     0.0
# 12403    0.0
# 2278     0.0
# 13197    1.0
# 30740    1.0
# 6626     0.0
# 25020    0.0
# 3082     0.0
# 6367     0.0
# 10936    0.0
# 19797    1.0
# 9994     0.0
# 815      0.0
# 24361    0.0
# 858      0.0
# 6708     1.0
# 30133    0.0
# 2759     1.0
# 17943    0.0
# 19614    0.0
# 12732    1.0
# 13488    0.0
# 20230    0.0
# 21071    0.0
# 23589    1.0
# 7390     0.0
# 1359     0.0
# 13499    1.0
# 13850    0.0
# 27823    0.0
#         ...
# 26035    0.0
# 1847     0.0
# 31775    1.0
# 21447    0.0
# 24864    1.0
# 19771    0.0
# 3117     0.0
# 26530    0.0
# 31299    0.0
# 13215    0.0
# 29439    0.0
# 10757    1.0
# 8014     0.0
# 26720    0.0
# 18187    0.0
# 15174    0.0
# 18510    0.0
# 31861    0.0
# 18650    0.0
# 4878     1.0
# 749      0.0
# 15155    0.0
# 15496    1.0
# 24194    0.0
# 14926    0.0
# 25408    0.0
# 27595    1.0
# 5002     0.0
# 1620     1.0
# 27983    0.0
# Name: wage_class, Length: 9768, dtype: float64

# %%
X_t = test_set_1.drop(['wage_class'], axis = 1)
X_t = X_t.astype(float)
X_t.head()
# Out:
#         age  workclass    fnlwgt  education  education_num  marital_status  \
# 4568   18.0        1.0  301948.0        4.0            9.0             3.0
# 12403  22.0        1.0  264874.0        4.0            9.0             3.0
# 2278   17.0        1.0  329783.0       13.0            6.0             3.0
# 13197  41.0        1.0  350387.0        1.0           13.0             3.0
# 30740  42.0        6.0  333530.0        2.0           10.0             1.0
#
#        occupation  relationship  race  sex  capital_gain  capital_loss  \
# 4568         13.0           2.0   1.0  1.0       34095.0           0.0
# 12403         2.0           2.0   1.0  0.0           0.0           0.0
# 2278          4.0           5.0   1.0  0.0           0.0           0.0
# 13197         6.0           4.0   1.0  1.0           0.0           0.0
# 30740         5.0           1.0   1.0  0.0           0.0           0.0
#
#        hours_per_week
# 4568              3.0
# 12403            40.0
# ...

# %%
dump_svmlight_file(X_t,y_t,'adult_test.dat',zero_based=True,multilabel=False)

# %%
X_train, y_train, X_test, y_test = load_svmlight_files(('adult_train.dat', 'adult_test.dat'))

# %%
params = {
    'objective': 'binary:logistic',
    'max_depth': 2,
    'learning_rate': 1.0,
    'silent': 1.0,
    'n_estimators': 5
}

# %%
from xgboost.sklearn import XGBClassifier
bst = XGBClassifier(**params).fit(X_train, y_train)

# %%
preds = bst.predict(X_test)
preds
# Out:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
correct = 0

for i in range(len(preds)):
    if (y_test[i] == preds[i]):
        correct += 1
        
acc = accuracy_score(y_test, preds)

print('Predicted correctly: {0}/{1}'.format(correct, len(preds)))
print('Error: {0:.4f}'.format(1-acc))
# Out:
# Predicted correctly: 7401/9768
# Error: 0.2423
